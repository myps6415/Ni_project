# %%
import pandas as pd

df = pd.read_csv('/Users/john.tung/Downloads/BB_bet_mark.csv', encoding="gb2312")
df.head()
# Out:
#    Unnamed: 0            账户名        下注日期  分类  游戏平台     下注金额     派彩金额   公司有效投注  \
# 0           1  1026065633cyx  2021-01-16  体育  BB体育   435.46   155.20   435.46
# 1           2         1122zz  2021-01-16  体育  BB体育  1112.00  1746.32  1112.00
# 2           3       123456FF  2021-01-16  体育  BT体育    35.00     0.00    35.00
# 3           4       123456FF  2021-01-16  体育  BB体育  3746.28  3009.17  3646.58
# 4           5     123456suno  2021-01-16  体育  BB体育   937.00     0.00   937.00
#
#        输赢     有效流水  结算单数             BB用户名        返水       上级代理        注册日期  \
# 0  280.26   380.00     3  BB_1026065633cyx   1.52000     win888  2019-05-26
# 1 -634.32  1112.00     9         BB_1122zz   4.44800    chg8888  2019-03-25
# 2   35.00    35.00     1       BB_123456FF   0.14000  dashui668  2019-03-16
# 3  737.11  3611.58    79       BB_123456FF  14.44632  dashui668  2019-03-16
# 4  937.00   443.00     9     BB_123456suno   1.77200      admin  2019-09-03
#
# ...

# %%
df = df[df['下注日期'].str.contains('2021-01')]
print(len(df))
df.head()
# Out:
# 528955
#    Unnamed: 0            账户名        下注日期  分类  游戏平台     下注金额     派彩金额   公司有效投注  \
# 0           1  1026065633cyx  2021-01-16  体育  BB体育   435.46   155.20   435.46
# 1           2         1122zz  2021-01-16  体育  BB体育  1112.00  1746.32  1112.00
# 2           3       123456FF  2021-01-16  体育  BT体育    35.00     0.00    35.00
# 3           4       123456FF  2021-01-16  体育  BB体育  3746.28  3009.17  3646.58
# 4           5     123456suno  2021-01-16  体育  BB体育   937.00     0.00   937.00
#
#        输赢     有效流水  结算单数             BB用户名        返水       上级代理        注册日期  \
# 0  280.26   380.00     3  BB_1026065633cyx   1.52000     win888  2019-05-26
# 1 -634.32  1112.00     9         BB_1122zz   4.44800    chg8888  2019-03-25
# 2   35.00    35.00     1       BB_123456FF   0.14000  dashui668  2019-03-16
# 3  737.11  3611.58    79       BB_123456FF  14.44632  dashui668  2019-03-16
# 4  937.00   443.00     9     BB_123456suno   1.77200      admin  2019-09-03
#
# ...

# %%
df.to_csv('/Users/john.tung/Downloads/BB_bet_mark.csv', encoding='utf_8_sig', index=False)

# %%
df = pd.read_csv('/Users/john.tung/Downloads/BB_load_mark.csv', encoding="gb2312")
print(len(df))
df.head()
# Out:
# 1919854
#    Unnamed: 0     账户名        下注日期      下注金额     派彩金额      输赢   公司有效投注  \
# 0           1  00000w  2020-12-07   4901.56  4739.01  162.55  4831.96
# 1           2  00000w  2020-12-08    791.77   551.44  240.33   790.77
# 2           3  00000w  2020-12-09  10030.00  9109.01  920.99  9798.47
# 3           4  00000w  2020-12-16    580.14   479.38  100.76   580.14
# 4           5  00000w  2020-12-21   1675.00  1755.17  -80.17  1420.37
#
#       有效流水       返水  结算单数  ...        注册日期 奖励VIP等级        升级日期      下次升级日期  \
# 0  4831.96  0.13320     2  ...  2020-12-04    VIP0  2020-12-04  2020-12-08
# 1   790.77  0.00300     2  ...  2020-12-04    VIP1  2020-12-08  2021-01-16
# 2  9798.47  0.10755     2  ...  2020-12-04    VIP1  2020-12-08  2021-01-16
# 3   580.14  0.03300     2  ...  2020-12-04    VIP1  2020-12-08  2021-01-16
# 4  1420.37  0.23700     2  ...  2020-12-04    VIP1  2020-12-08  2021-01-16
#
#   充值次数    存款金额  提款次数  提款金额      下注周      注册周
# ...

# %%
df = df[df['下注日期'].str.contains('2021-01')]
print(len(df))
df.head()
# Out:
# 391318
#     Unnamed: 0            账户名        下注日期    下注金额     派彩金额      输赢  公司有效投注  \
# 7            8         00000w  2021-01-06  3865.0  3664.52  200.48  3865.0
# 8            9         00000w  2021-01-07   681.0   979.72 -298.72   521.0
# 9           10         00000w  2021-01-08  1535.0  1226.20  308.80  1535.0
# 10          11         00000w  2021-01-09  2338.0  2137.02  200.98  2338.0
# 50          51  00008374wwyy0  2021-01-07    38.0    19.00   19.00    38.0
#
#       有效流水     返水  结算单数  ...        注册日期 奖励VIP等级        升级日期      下次升级日期 充值次数  \
# 7   3865.0  0.021     2  ...  2020-12-04    VIP1  2020-12-08  2021-01-16    1
# 8    521.0  0.009     2  ...  2020-12-04    VIP1  2020-12-08  2021-01-16    1
# 9   1535.0  0.027     2  ...  2020-12-04    VIP1  2020-12-08  2021-01-16    1
# 10  2338.0  0.012     2  ...  2020-12-04    VIP1  2020-12-08  2021-01-16    1
# 50    38.0  0.152     1  ...  2020-08-08    VIP3  2021-01-03  2021-01-16    0
#
# ...

# %%
df.to_csv('/Users/john.tung/Downloads/BB_load_mark.csv', encoding='utf_8_sig', index=False)
